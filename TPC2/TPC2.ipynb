# %%
print("Vamos jogar ao Adivinha o Número!")
resposta =(input("Prima 1 se quer adivinhar ou Prima 2 se quer que o computador adivinhe."))
if resposta == "1":
    i = 1
    import random
    num = random.randint(0,100)
    a = int(input("Qual número achas que é (0 a 100)?"))
    while num != a:
        if num > a:
            a = int(input("O número que pensei é Maior. Tente Novamente"))
        else:
            a = int(input("O número que pensei é Menor. Tente Novamente"))
        i = i + 1   
    print(f"Acertou! O número que pensei foi o {num}, e precisou de {i} tentativas!")
elif resposta == "2":
    print("As suas opções de resposta são: Acertou, O número que pensei é Maior ou O número que pensei é Menor")
    min = 0
    max = 100
    i = 1 
    b = (min + max) // 2
    c = input(f"O número é {b}?")
    while c != "Acertou":
        if c == "O número que pensei é Maior":
            min = b + 1
            i = i + 1
        else:
            max = b - 1
            i = i + 1
        b = (min + max) // 2
        c = input(f"O número é {b}?")
    print(f"O número que pensou foi {b}! Precisei de {i} tentativas para acertar.")
else:
    print("Erro! Tem que primir 1 ou 2")
# Out:
# Vamos jogar ao Adivinha o Número!
# Acertou! O número que pensei foi o 67, e precisou de 6 tentativas!
